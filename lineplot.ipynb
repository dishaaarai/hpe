# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:\\Users\\disha\\Downloads\\data_1.csv",parse_dates=['START_TIME'])

# %%
df.set_index('START_TIME', inplace=True)

# %%
plt.rcParams['figure.figsize'] = [20, 5]

# %%
for col in df.columns:
    plt.plot(df.index, df[col])
    plt.title(col)
    plt.xlabel('Date')
    plt.ylabel('Value')
    plt.savefig(f"{col}_line_chart.png")
    plt.show()

# %%
#to find missing timeseries data
df = pd.read_csv("C:\\Users\\disha\\Downloads\\data_1.csv",parse_dates=['START_TIME'])
df['START_TIME']=pd.to_datetime(df['START_TIME'])
set1=set(pd.date_range(df['START_TIME'].min(),df['START_TIME'].max(),freq='H'))
set2=set(df['START_TIME'])
set1-set2
# Out:
# {Timestamp('2021-07-29 21:00:00', freq='H'),
#  Timestamp('2021-07-29 22:00:00', freq='H'),
#  Timestamp('2021-07-29 23:00:00', freq='H'),
#  Timestamp('2021-07-30 00:00:00', freq='H'),
#  Timestamp('2021-07-30 01:00:00', freq='H'),
#  Timestamp('2021-07-30 02:00:00', freq='H'),
#  Timestamp('2021-07-30 03:00:00', freq='H'),
#  Timestamp('2021-07-30 04:00:00', freq='H')}
